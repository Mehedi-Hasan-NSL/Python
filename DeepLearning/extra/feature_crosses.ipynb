# %% [markdown]
# <a href="https://colab.research.google.com/github/raqueeb/TensorFlow2/blob/master/feature_crosses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ডিপ লার্নিং কেন? নন-লিনিয়ার সমস্যা, ফিচার ক্রস
#
# এই প্রশ্নটা প্রায় অনেকেই করেন, মেশিন লার্নিং থাকতে ডিপ লার্নিং কেন দরকার পড়লো? এর উত্তর সবার জানা, তবে যে জন্য আমি ডিপ লার্নিংয়ে এসেছি সেটা আলাপ করি বরং। আমার একটা সমস্যা হচ্ছে, যে কোন ডাটা পেলেই সেটাকে আগে কাগজে প্লট করে ফেলি। তাহলে সেটা বুঝতে সুবিধা হয়।
#
# মনে আছে আমাদের আইরিশ ডাটা সেটের কথা? সেখানে সবগুলো প্রজাতির ডাটাকে প্লট করলে কিছুটা এরকম দেখা যেত। তিন প্রজাতিকে ছবির মধ্যে আলাদা করা খুব একটা সমস্যা ছিল না। কারণ তিনটা ছবির মধ্যে দুটো লাইন বা সরলরেখা টানলেই কিন্তু তিনটা প্রজাতিকে আলাদা করে ফেলা যেত। এক পিকচার থেকে আরেক পিকচারের ডিসিশন সারফেস এবং ডিসিশন বাউন্ডারি সরলরেখার।
#
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/assets/iris.png" alt="আইরিশ ডেটাসেটের ডিসিশন বাউন্ডারি"> চিত্রঃ আইরিশ ডেটাসেটের ডিসিশন বাউন্ডারি
#
# ---
# এখানে ইচ্ছেমতো সাইকিট-লার্ন এবং টেন্সর-ফ্লো ব্যবহার করছি কাজের সুবিধার্থে। কখন কোনটা কাজে লাগে সেটা জানবেন নিজে নিজে।

# %% [markdown]
# ## দুটো ফিচার নিয়ে আইরিশ ডেটাসেটকে প্লট করি
#
# সরল রেখায় ডিসিশন সারফেস/বাউন্ডারি বানানো যায় সহজে। কোড কমানোর জন্য 'plot_decision_regions' নামের একটা হেলপার ফাংশন ব্যবহার করি।

# %%
conda install mlxtend --channel conda-forge
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DELL\Anaconda3
#
#   added / updated specs:
#     - mlxtend
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa244fe_0         3.1 MB  conda-forge
#     mlxtend-0.18.0             |     pyhd3deb0d_0         1.2 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   mlxtend            conda-forge/noarch::mlxtend-0.18.0-pyhd3deb0d_0
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-4.10.3-py38haa95532_0 --> conda-forge::conda-4.10.3-py38haa244fe_0
#
#
#
# Downloading and Extracting Packages
#
# mlxtend-0.18.0       | 1.2 MB    |            |   0%
# mlxtend-0.18.0       | 1.2 MB    | 1          |   1%
# mlxtend-0.18.0       | 1.2 MB    | #          |  10%
# mlxtend-0.18.0       | 1.2 MB    | ##8        |  28%
# mlxtend-0.18.0       | 1.2 MB    | #####7     |  58%
# mlxtend-0.18.0       | 1.2 MB    | #######5   |  76%
# mlxtend-0.18.0       | 1.2 MB    | #########1 |  91%
# mlxtend-0.18.0       | 1.2 MB    | ########## | 100%
#
# conda-4.10.3         | 3.1 MB    |            |   0%
# conda-4.10.3         | 3.1 MB    |            |   1%
# conda-4.10.3         | 3.1 MB    | #4         |  14%
# conda-4.10.3         | 3.1 MB    | ##2        |  23%
# conda-4.10.3         | 3.1 MB    | ###1       |  31%
# conda-4.10.3         | 3.1 MB    | #####5     |  55%
# conda-4.10.3         | 3.1 MB    | ######5    |  66%
# conda-4.10.3         | 3.1 MB    | #######5   |  76%
# conda-4.10.3         | 3.1 MB    | ########3  |  84%
# conda-4.10.3         | 3.1 MB    | #########1 |  91%
# conda-4.10.3         | 3.1 MB    | #########7 |  98%
# conda-4.10.3         | 3.1 MB    | ########## | 100%
#
# python_abi-3.8       | 4 KB      |            |   0%
# python_abi-3.8       | 4 KB      | ########## | 100%
# python_abi-3.8       | 4 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import datasets
from sklearn.svm import SVC
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt
# %matplotlib inline

# দুটো ফিচার নিচ্ছি
iris = datasets.load_iris()
X = iris.data[:, [0, 2]]
#print(X)
y = iris.target

# ক্লাসিফায়ার ট্রেনিং করছি
svm = SVC(C=0.5, kernel='linear')
svm.fit(X, y)


# প্লট করছি নতুন লাইব্রেরি দিয়ে
plot_decision_regions(X, y, clf=svm, legend=2)

# দু পাশের লেখাগুলো সেট করছি
plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.title('SVM on Iris')
plt.show()

# %% [markdown]
# বয়সের সাথে ওজন বাড়বে, বাড়ি স্কয়ার ফিট এর সাথে দাম বাড়বে, এধরনের লিনিয়ার সম্পর্কগুলোতে ডাটাকে প্লট করলে সেগুলোকে সোজা লাইন দিয়ে আলাদা করে দেখা যায় সহজে। কিন্তু ডাটা যদি এমন হয়? কিভাবে একটা লাইন দিয়ে দুটো ফিচারকে ভাগ করবেন?
#
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/assets/fc1.png" alt="নন-লিনিয়ার ক্লাসিফিকেশন সমস্যা">
#
# চিত্রঃ নন-লিনিয়ার ক্লাসিফিকেশন সমস্যা
#
# এটা নন-লিনিয়ার ক্লাসিফিকেশন সমস্যা। নন-লিনিয়ার এর সমস্যা হচ্ছে তাদের 'ডিসিশন সারফেস' সরলরেখা নয়। এই ছবিতে যদি দুটো ফিচার থাকে তাহলে সেটা দিয়ে এই সমস্যার সমাধান করা সম্ভব নয়। সেটার জন্য প্রয়োজন ফিচার ক্রস। মানে এই নতুন ফিচার কয়েকটা ফিচার স্পেসের গুণফলের আউটকাম নন-লিনিয়ারিটিকে এনকোড করে মানে আরেকটা সিনথেটিক ফিচার তৈরি করে সেটার মাধ্যমে এই নন-লিনিয়ারিটিকে কিছুটা ডিল করা যায়। ক্রস এসেছে ক্রস প্রোডাক্ট থেকে। এখানে x1 = x2x3 (সাবস্ক্রিপ্ট হবে)

# %% [markdown]
# ## একটা নন-লিনিয়ারিটির উদাহরণ দেখি আসল ডেটা থেকে

# %%
import pandas as pd
import numpy as np
import sklearn

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## ভার্সন চেক করি

# %%
sklearn.__version__
# Out:
# '0.24.1'

# %%
try:
  # %tensorflow_version only exists in Colab.
  # শুধুমাত্র জুপিটার নোটবুক/কোলাবে চেষ্টা করবো টেন্সর-ফ্লো ২.০ এর জন্য
  # %tensorflow_version 2.x
except Exception:
  pass

# %% [markdown]
# ## ১. ডেটাকে আমরা লোড করে সেটাকে ট্রেইন এবং টেস্টসেটে ভাগ করি

# %% [markdown]
# ধরুন আপনি ডাটা প্লট করে দেখলেন এই অবস্থা। কি করবেন? নিচের ছবি দেখুন। এই ডাটাসেটে অক্ষাংশ, দ্রাঘিমাংশ, ভূমির উচ্চতা ইত্যাদি আছে। আমরা সবগুলোর মধ্যে শুধুমাত্র অক্ষাংশ, দ্রাঘিমাংশ প্লট করছি। দেখুন কি অবস্থা। একটা ফিচার ভেতরে আরেকটা ঘিরে রয়েছে সেটাকে চারপাশ দিয়ে। এখন কিভাবে এদুটোকে আলাদা করবেন? সোজা লাইন টেনে সম্ভব না। শুরুতে চেষ্টা করি সাপোর্ট ভেক্টর মেশিন, এরপর নিউরাল নেটওয়ার্ক দিয়ে।

# %%
# df = pd.read_csv('geoloc_elev.csv')
df = pd.read_csv('https://raw.githubusercontent.com/raqueeb/TensorFlow2/master/datasets/geoloc_elev.csv')

# আমাদের দুটো ফিচার হলেই যথেষ্ট 
X = df[['lat', 'lon']].values
y = df['target'].values

# %%
df.plot(kind='scatter',
        x='lat',
        y='lon',
        c='target',
        cmap='bwr');

# %%
# এখানে সাপোর্ট ভেক্টর মেশিন ব্যবহার করছি
from sklearn.svm import SVC
clf = SVC(gamma = "auto")
#clf = SVC(kernel = "poly")
clf.fit(X, y)
# Out:
# SVC(gamma='auto')

# %%
# প্লটিং এর কিছু লাইব্রেরি ব্যবহার করছি, plot_decision_regions লাইব্রেরিটা বেশ ভালো
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X=X, y=y, clf=clf, legend=2)
plt.xlabel("x", size=5)
plt.ylabel("y", size=5)
plt.title('SVM Decision Region Boundary', size=16)
plt.show()

# %% [markdown]
# মেশিন লার্নিং এ ফিচার ক্রসের সুবিধা থাকলেও আমার পছন্দের ব্যাপার হচ্ছে মডেলে নন লিনিয়ারিটি ঢুকানো। মডেলে নন লিনিয়ারিটি ঢুকাতে গেলে নিউরাল নেটওয়ার্ক ভালো একটা উপায়। আমরা একটা ছবি আঁকি লিনিয়ার মডেলের। তিনটে ইনপুট ফিচার। ইনপুট ফিচারের সাথে ওয়েটকে যোগ করে নিয়ে এলাম আউটপুটে। আপনার কি মনে হয় এভাবে মডেলে নন-লিনিয়ারিটি ঢুকানোর সম্ভব? আপনি বলুন।
#
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/start-page/linear_net.png">
#
# চিত্রঃ তিনটা ইনপুট যাচ্ছে একটা নিউরাল নেটওয়ার্কে

# %% [markdown]
# পরের ছবিতে আমরা একটা হিডেন লেয়ার যোগ করি। হিডেন লেয়ারের অর্থ হচ্ছে এর মধ্যে কিছু মাঝামাঝি ভ্যালু যোগ করা। আগের ইনপুট লেয়ার থেকে এই লেয়ারে তাদের ওয়েটগুলোর যোগফল পাঠিয়ে দিচ্ছে সামনের লেয়ারে। এখানে সামনে লেয়ার হচ্ছে আউটপুট। ইনপুট থেকে ওয়েট যোগ করে সেগুলোকে পাঠিয়ে দিচ্ছে আউটপুট লেয়ারে। ইংরেজিতে আমরা বলি 'ওয়েটেড সাম অফ প্রিভিয়াস নোডস'। এখনো কি মডেলটা লিনিয়ার? মডেল অবশ্যই লিনিয়ার হবে কারণ আমরা এ পর্যন্ত যা করেছি তা সব লিনিয়ার ইনপুটগুলোকেই একসাথে করেছি। নন-লিনিয়ারিটি যোগ করার মতো এখনো কিছু করিনি।
#
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/start-page/1hidden.png">
# চিত্রঃ যোগ করলাম প্রথম হিডেন লেয়ার, লিনিয়ারিটি বজায় থাকবে?
#
# এরকম করে আমরা যদি আরেকটা হিডেন লেয়ার যোগ করি তাহলে কি হবে? নন লিনিয়ার কিছু হতে পারে? না। আমরা যতই লেয়ার বাড়াই না কেন এই আউটপুট হচ্ছে আসলে ইনপুটের একটা ফাংশন। মানে হচ্ছে ইনপুটের ওয়েট গুলোর একটা যোগফল। যাই যোগফল হোকনা কেন সবই লিনিয়ার। এই যোগফল আসলে আমাদের নন লিনিয়ার সমস্যা মেটাবে না।
#
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/start-page/2hidden.png">
# চিত্রঃ যোগ করলাম দ্বিতীয় হিডেন লেয়ার, লিনিয়ারিটি বজায় থাকবে?

# %% [markdown]
# একটা নন লিনিয়ার সমস্যাকে মডেল করতে গেলে আমাদের মডেলে যোগ করতে হবে নন লিনিয়ার কিছু ফাংশন। ব্যাপারটা আমাদেরকে নিজেদেরকেই ঢোকাতে হবে। সবচেয়ে মজার কথা হচ্ছে আমরা এই ইনপুটগুলোকে পাইপ করে হিডেন লেয়ারের শেষে একটা করে নন লিনিয়ার ফাংশন যোগ করে দিতে পারি। এই ছবিটা দেখুন। আমরা এক নাম্বার হিডেন লেয়ার এর পর একটা করে নন লিনিয়ার ফাংশন যোগ করে দিয়েছি যাতে সেটার আউটপুট সে পাঠাতে পারে দ্বিতীয় হিডেন লেয়ারে। এই ধরনের নন লিনিয়ার ফাংশনকে আমরা এর আগেও বলেছি অ্যাক্টিভেশন ফাংশন।

# %% [markdown]
# আমাদের পছন্দের অ্যাক্টিভেশন ফাংশন হচ্ছে রেল্যু, রেকটিফাইড লিনিয়ার ইউনিট অ্যাক্টিভেশন ফাংশন। কাজে এটা স্মার্ট, অনেকের থেকে ভালো আর সে কারণে এর ব্যবহার অনেক বেশি। ভুল হবার চান্স কম। ডায়াগ্রাম দেখলেই বুঝতে পারবেন - যদি ইনপুট শূন্য হয় তাহলে আউটপুট ০ আর ইনপুটের মান ০ থেকে বেশি হয় তাহলে সেটার আউটপুটে যাবে পরের লেয়ারে যাওয়ার জন্য।
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/start-page/relu.png">
# চিত্রঃ ইনপুটের সবকিছুর 'ওয়েটেড সাম' থেকে ০ আসলে সেটাই থাকবে বেশি হলে ১, মানে পরের লেয়ারে পার

# %% [markdown]
# আমরা যখন অ্যাক্টিভেশন ফাংশন যোগ করব তার সঙ্গে বেশি বেশি লেয়ার মডেলে ভালো কাজ করে। একটা নন লিনিয়ারিটি আরেকটা নন লিনিয়ারিটির উপর থাকাতে মডেল অনেক কমপ্লেক্স সম্পর্ক ধরতে পারে ইনপুট থেকে আউটপুট পর্যন্ত। মডেলের প্রতিটা লেয়ার তার অংশে কমপ্লেক্স জিনিসগুলো এক্সট্রাক্ট করতে পারে সেই কারণেই। অ্যাক্টিভেশন ফাংশন ছাড়া একটা নিউরাল নেটওয়াক আসলে আরেকটা লিনিয়ার রিগ্রেশন মডেল। এদিকে অ্যাক্টিভেশন ফাংশনে ব্যাক-প্রপাগেশন সম্ভব করে কারণ এর গ্রেডিয়েন্ট, তার এরর, ওয়েট এবং বায়াসকে আপডেট পাঠায়। শুরুর দিকের অ্যাক্টিভেশন ফাংশন হচ্ছে সিগময়েড। যার কাজ হচ্ছে যাই পাক না কেন সেটাকে ০ অথবা ১ এ পাঠিয়ে দেবে।
# <img src="https://raw.githubusercontent.com/raqueeb/deep_learning_book/master/start-page/sigmoid.png">
# চিত্রঃ ইনপুটের সবকিছুর 'ওয়েটেড সাম' পাল্টে দেবে ০ থেকে ১ এর মধ্যে এই সিগময়েড
#
# আবারো বলছি - সিগময়েড অ্যাক্টিভেশন ফাংশন লেয়ারগুলোর ইনপুটের/আউটপুটের যোগফলকে ০ অথবা ১ এর মধ্যে ফেলে দেয়। হয় এসপার না হলে ওসপার। লিনিয়ারিটির কোন স্কোপ থাকবে না। একটা ছবি দেখুন। ইকুয়েশন সহ।

# %% [markdown]
# আমার আরেকটা পছন্দের অ্যাক্টিভেশন ফাংশন হচ্ছে সফটম্যাক্স। এটা সাধারণত আমরা ব্যবহার করি দুইয়ের বেশি ক্লাসিফিকেশন সমস্যা হ্যান্ডেল করতে। সিগময়েড ভালো যখন আমরা দুটো ক্লাসিফিকেশন করি, তবে মাল্টিপল ক্লাসিফিকেশন এর জন্য সফটম্যাক্স অসাধারণ। যখন আউটপুট লেয়ার একটার সাথে আরেকটা 'মিউচুয়ালি এক্সক্লুসিভ' হয়, মানে কোন আউটপুট একটার বেশী আরেকটার ঘরে পড়বে না তাহলে সেটা 'সফটম্যাক্'স হ্যান্ডেল করবে। আমাদের যেকোনো শার্ট অথবা হাতে লেখা MNIST ইমেজগুলো যেকোন একটা ক্লাসেই পড়বে তার বাইরে নয়।

# %% [markdown]
# ## ট্রেনিং/টেস্ট স্প্লিট করা

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
    test_size = 0.3, random_state=0)

# %% [markdown]
# ## একটা লজিস্টিক রিগ্রেশন করি
#
# আপনার মনে হচ্ছে কি হবে?

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## একটা প্লটিং দেখি
#
# কিছুই হয়নি।

# %%
hticks = np.linspace(-2, 2, 101)
#print(hticks)
vticks = np.linspace(-2, 2, 101)
aa, bb = np.meshgrid(hticks, vticks)

ab = np.c_[aa.ravel(), bb.ravel()]
#print(ab)
c = lr.predict_proba(ab)[:,1]
cc = c.reshape(aa.shape)

ax = df.plot(kind='scatter', c='target', x='lat', y='lon', cmap='bwr')
ax.contourf(aa, bb, cc, cmap='bwr', alpha=0.5)

# %% [markdown]
# ## ২. একদম বেসিক নিউরাল নেটওয়ার্কে দেখি
# ১টা ইনপুট লেয়ার, ১টা নিউরন, ১টা আউটপুট।

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, input_dim=2, activation='tanh'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(tf.keras.optimizers.SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])
result = model.fit(X_train, y_train, epochs=40, validation_split=0.2)
# Out:
# Epoch 1/40
#  1/27 [>.............................] - ETA: 0s - loss: 0.6734 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 27/27 [==============================] - 0s 12ms/step - loss: 0.6523 - accuracy: 0.6119 - val_loss: 0.6671 - val_accuracy: 0.6143
# Epoch 2/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6378 - accuracy: 0.6667 - val_loss: 0.6823 - val_accuracy: 0.6143
# Epoch 3/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6396 - accuracy: 0.6667 - val_loss: 0.6756 - val_accuracy: 0.6143
# Epoch 4/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6406 - accuracy: 0.6667 - val_loss: 0.6747 - val_accuracy: 0.6143
# Epoch 5/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6391 - accuracy: 0.6667 - val_loss: 0.6693 - val_accuracy: 0.6143
# Epoch 6/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6387 - accuracy: 0.6667 - val_loss: 0.6688 - val_accuracy: 0.6143
# Epoch 7/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.6667 - val_loss: 0.6684 - val_accuracy: 0.6143
# Epoch 8/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6377 - accuracy: 0.6667 - val_loss: 0.6748 - val_accuracy: 0.6143
# Epoch 9/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.6667 - val_loss: 0.6676 - val_accuracy: 0.6143
# Epoch 10/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6400 - accuracy: 0.6667 - val_loss: 0.6696 - val_accuracy: 0.6143
# Epoch 11/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6374 - accuracy: 0.6667 - val_loss: 0.6843 - val_accuracy: 0.6143
# Epoch 12/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6391 - accuracy: 0.6667 - val_loss: 0.6852 - val_accuracy: 0.6143
# Epoch 13/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.6667 - val_loss: 0.6787 - val_accuracy: 0.6143
# Epoch 14/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.6667 - val_loss: 0.6737 - val_accuracy: 0.6143
# Epoch 15/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6381 - accuracy: 0.6667 - val_loss: 0.6673 - val_accuracy: 0.6143
# Epoch 16/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6379 - accuracy: 0.6667 - val_loss: 0.6672 - val_accuracy: 0.6143
# Epoch 17/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6379 - accuracy: 0.6667 - val_loss: 0.6676 - val_accuracy: 0.6143
# Epoch 18/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6386 - accuracy: 0.6667 - val_loss: 0.6725 - val_accuracy: 0.6143
# Epoch 19/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6383 - accuracy: 0.6667 - val_loss: 0.6831 - val_accuracy: 0.6143
# Epoch 20/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6381 - accuracy: 0.6667 - val_loss: 0.6696 - val_accuracy: 0.6143
# Epoch 21/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6379 - accuracy: 0.6667 - val_loss: 0.6772 - val_accuracy: 0.6143
# Epoch 22/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6386 - accuracy: 0.6667 - val_loss: 0.6696 - val_accuracy: 0.6143
# Epoch 23/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6376 - accuracy: 0.6667 - val_loss: 0.6996 - val_accuracy: 0.6143
# Epoch 24/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6393 - accuracy: 0.6667 - val_loss: 0.6783 - val_accuracy: 0.6143
# Epoch 25/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.6667 - val_loss: 0.6674 - val_accuracy: 0.6143
# Epoch 26/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6379 - accuracy: 0.6667 - val_loss: 0.6771 - val_accuracy: 0.6143
# Epoch 27/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6372 - accuracy: 0.6667 - val_loss: 0.6751 - val_accuracy: 0.6143
# Epoch 28/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6387 - accuracy: 0.6667 - val_loss: 0.6836 - val_accuracy: 0.6143
# Epoch 29/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.6667 - val_loss: 0.6715 - val_accuracy: 0.6143
# Epoch 30/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6375 - accuracy: 0.6667 - val_loss: 0.6766 - val_accuracy: 0.6143
# Epoch 31/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.6667 - val_loss: 0.6869 - val_accuracy: 0.6143
# Epoch 32/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6389 - accuracy: 0.6667 - val_loss: 0.6775 - val_accuracy: 0.6143
# Epoch 33/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6367 - accuracy: 0.6667 - val_loss: 0.6680 - val_accuracy: 0.6143
# Epoch 34/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6376 - accuracy: 0.6667 - val_loss: 0.6684 - val_accuracy: 0.6143
# Epoch 35/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6373 - accuracy: 0.6667 - val_loss: 0.6682 - val_accuracy: 0.6143
# Epoch 36/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6378 - accuracy: 0.6667 - val_loss: 0.6693 - val_accuracy: 0.6143
# Epoch 37/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.6667 - val_loss: 0.6765 - val_accuracy: 0.6143
# Epoch 38/40
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6365 - accuracy: 0.6667 - val_loss: 0.6674 - val_accuracy: 0.6143
# Epoch 39/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6361 - accuracy: 0.6667 - val_loss: 0.6708 - val_accuracy: 0.6143
# Epoch 40/40
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6325 - accuracy: 0.6667 - val_loss: 0.6593 - val_accuracy: 0.6143

# %% [markdown]
# ## অ্যাক্যুরেসি প্লটিং দেখি

# %%
pd.DataFrame(result.history).plot(ylim=(-0.05, 1.05))

# %% [markdown]
# ## ডিসিশন বাউন্ডারি কি ঠিক হলো?

# %%
hticks = np.linspace(-2, 2, 101)
vticks = np.linspace(-2, 2, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]

# c = model.predict_proba(ab)[:,1]
c = model.predict_proba(ab)
cc = c.reshape(aa.shape)

ax = df.plot(kind='scatter', c='target', x='lat', y='lon', cmap='bwr')
ax.contourf(aa, bb, cc, cmap='bwr', alpha=0.5)
# Out:
# WARNING:tensorflow:From <ipython-input-22-2223453c2943>:7: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(4, input_dim=2, activation='tanh'),
    # এই লেয়ার পরে যোগ করে আমরা দেখবো 
    #tf.keras.layers.Dense(4, activation='tanh'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(tf.keras.optimizers.SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])
h = model.fit(X_train, y_train, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 0s 10ms/step - loss: 0.6533 - accuracy: 0.6169 - val_loss: 0.6488 - val_accuracy: 0.6381
# Epoch 2/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6283 - accuracy: 0.6582 - val_loss: 0.6143 - val_accuracy: 0.6381
# Epoch 3/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5644 - accuracy: 0.6614 - val_loss: 0.5185 - val_accuracy: 0.6381
# Epoch 4/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.8201 - val_loss: 0.3572 - val_accuracy: 0.8857
# Epoch 5/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3107 - accuracy: 0.9058 - val_loss: 0.2377 - val_accuracy: 0.9238
# Epoch 6/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.1811 - accuracy: 0.9640 - val_loss: 0.1163 - val_accuracy: 1.0000
# Epoch 7/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9958 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 8/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9979 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 9/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9989 - val_loss: 0.0325 - val_accuracy: 1.0000
# Epoch 10/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9989 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 11/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 0.9989 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 12/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 13/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9989 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 14/20
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 15/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.9989 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 16/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 17/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 18/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 19/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 20/20
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000

# %% [markdown]
# ## একটা কনফিউশন ম্যাট্রিক্স তৈরি করি

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = model.predict_classes(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)

pd.DataFrame(cm,
             index=["Miss", "Hit"],
             columns=['pred_Miss', 'pred_Hit'])
# Out:
#       pred_Miss  pred_Hit
# Miss        311         0
# Hit           0       139

# %%
train_score = model.evaluate(X_train, y_train, verbose=0)[1]
test_score = model.evaluate(X_test, y_test,  verbose=0)[1]

print("""Accuracy scores:
   Train:\t{:0.3}
   Test:\t{:0.3}""".format(train_score, test_score))
# Out:
# Accuracy scores:
#    Train:	1.0
#    Test:	1.0

# %% [markdown]
# ## নতুন ডিসিশন বাউন্ডারি, অল্প লেয়ারেই
#
# একদম পারফেক্ট হয়েছে বলতে গেলে। এতো অল্প লেয়ারে। লেয়ার বাড়িয়ে দেখুন, কমেন্ট সরিয়ে আবার চালান মডেল। আরো ভালো রেজাল্ট পাবেন।

# %%
hticks = np.linspace(-2, 2, 101)
vticks = np.linspace(-2, 2, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]

c = model.predict(ab)
print(c)
cc = c.reshape(aa.shape)
#print(cc)
ax = df.plot(kind='scatter', c='target', x='lat', y='lon', cmap='bwr')
ax.contourf(aa, bb, cc, cmap='bwr', alpha=0.5)
# Out:
# [[2.2230148e-03]
#  [2.2350848e-03]
#  [2.2507310e-03]
#  ...
#  [9.5843880e-06]
#  [8.5259617e-06]
#  [7.6379665e-06]]
